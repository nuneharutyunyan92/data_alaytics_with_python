# %%
import pandas as pd
import matplotlib.pyplot as plt

df_demo = pd.DataFrame({
    "category": ["A", "B", "C", "D", "E", "F"],
    "value": [120, 65, 75, 50, 30, 15]
})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#       3
#       4 df_demo = pd.DataFrame({
#       5     "category": ["A", "B", "C", "D", "E", "F"],
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
plt.figure()
plt.bar(df_demo["category"], df_demo["value"])
plt.title("Poor Example: Unsorted Categories with Default Presentation")
plt.xlabel("Category")
plt.ylabel("Value")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt.figure()
#       2 plt.bar(df_demo["category"], df_demo["value"])
#       3 plt.title("Poor Example: Unsorted Categories with Default Presentation")
#       4 plt.xlabel("Category")
#
# NameError: name 'plt' is not defined
